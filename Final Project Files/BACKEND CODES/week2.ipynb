# %%
pip install pycocotools matplotlib opencv-python
# Out:
# Requirement already satisfied: pycocotools in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (2.0.10)
# Requirement already satisfied: matplotlib in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (3.10.3)
# Requirement already satisfied: opencv-python in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (4.12.0.88)
# Requirement already satisfied: numpy in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from pycocotools) (2.2.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install albumentations==1.4.4
# Out:
# Requirement already satisfied: albumentations==1.4.4 in c:\users\kiit0001\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: numpy>=1.24.4 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from albumentations==1.4.4) (2.2.5)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from albumentations==1.4.4) (1.15.3)
# Requirement already satisfied: scikit-image>=0.21.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from albumentations==1.4.4) (0.25.0)
# Requirement already satisfied: PyYAML in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from albumentations==1.4.4) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from albumentations==1.4.4) (4.13.2)
# Requirement already satisfied: scikit-learn>=1.3.2 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from albumentations==1.4.4) (1.6.1)
# Requirement already satisfied: pydantic>=2.6.4 in c:\users\kiit0001\anaconda3\lib\site-packages (from albumentations==1.4.4) (2.10.3)
# Requirement already satisfied: opencv-python-headless>=4.9.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from albumentations==1.4.4) (4.12.0.88)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from pydantic>=2.6.4->albumentations==1.4.4) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\kiit0001\anaconda3\lib\site-packages (from pydantic>=2.6.4->albumentations==1.4.4) (2.27.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\kiit0001\anaconda3\lib\site-packages (from scikit-image>=0.21.0->albumentations==1.4.4) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from scikit-image>=0.21.0->albumentations==1.4.4) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\kiit0001\anaconda3\lib\site-packages (from scikit-image>=0.21.0->albumentations==1.4.4) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\kiit0001\anaconda3\lib\site-packages (from scikit-image>=0.21.0->albumentations==1.4.4) (2025.2.18)
# Requirement already satisfied: packaging>=21 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from scikit-image>=0.21.0->albumentations==1.4.4) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\kiit0001\anaconda3\lib\site-packages (from scikit-image>=0.21.0->albumentations==1.4.4) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.3.2->albumentations==1.4.4) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kiit0001\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.3.2->albumentations==1.4.4) (3.6.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os, random, numpy as np, matplotlib.pyplot as plt, cv2
from pycocotools.coco import COCO
import albumentations as A

# Paths (update if needed)
imgDir  = r"C:\Users\KIIT0001\Desktop\infosys aiml\val2017\val2017"
annFile = r"C:\Users\KIIT0001\Desktop\infosys aiml\annotations_trainval2017\annotations\instances_val2017.json"

# Load COCO
coco = COCO(annFile)

# Get all image IDs
imgIds = coco.getImgIds()
random.shuffle(imgIds)

# Select 10 random images
sample_imgIds = imgIds[:10]

# Define STRONG augmentation pipeline
transform = A.Compose([
    A.Resize(255, 255),
    A.RandomRotate90(),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.ShiftScaleRotate(shift_limit=0.2, scale_limit=0.3, rotate_limit=60, p=0.7),
    A.RandomBrightnessContrast(p=0.5),
    A.HueSaturationValue(p=0.5),
    A.GaussianBlur(blur_limit=(3, 7), p=0.4),
    A.RandomGamma(p=0.4),
    A.CoarseDropout(max_holes=8, max_height=40, max_width=40, p=0.3)  # random cutout
])

for idx, imgId in enumerate(sample_imgIds, 1):
    imgInfo = coco.loadImgs(imgId)[0]

    # Load image
    imgPath = os.path.join(imgDir, imgInfo['file_name'])
    image = cv2.cvtColor(cv2.imread(imgPath), cv2.COLOR_BGR2RGB)

    # Load annotations
    annIds = coco.getAnnIds(imgIds=imgInfo['id'])
    anns = coco.loadAnns(annIds)

    # Build combined mask
    mask = np.zeros((imgInfo['height'], imgInfo['width']), dtype=np.uint8)
    for ann in anns:
        mask |= coco.annToMask(ann).astype(np.uint8)

    # Resize + normalize original
    image_resized = cv2.resize(image, (255, 255)).astype(np.float32) / 255.0
    mask_resized = cv2.resize(mask, (255, 255), interpolation=cv2.INTER_NEAREST)

    # Masked original image
    masked_image = image_resized.copy()
    masked_image[mask_resized == 0] = 0

    # Apply several augmentations for the same image
    for aug_round in range(3):  # show 3 augmentations per image
        augmented = transform(image=image, mask=mask)
        aug_img, aug_mask = augmented["image"], augmented["mask"]
     # Normalize
        aug_img_norm = aug_img.astype(np.float32) / 255.0

        # Foreground only
        aug_masked_image = aug_img_norm.copy()
        aug_masked_image[aug_mask == 0] = 0

        # Display results
        fig, ax = plt.subplots(1, 4, figsize=(18, 6))
        ax[0].imshow(image_resized)
        ax[0].set_title("Original Resized + Normalized")
        ax[0].axis("off")

        ax[1].imshow(masked_image)
        ax[1].set_title("Masked Giraffe (Foreground Only)")
        ax[1].axis("off")

        ax[2].imshow(aug_img_norm)
        ax[2].set_title(f"Augmented Image {aug_round+1}")
        ax[2].axis("off")

        ax[3].imshow(aug_masked_image)
        ax[3].set_title(f"Masked Foreground (Aug {aug_round+1})")
        ax[3].axis("off")

        plt.show()
# Out:
# loading annotations into memory...
# Done (t=1.42s)
# creating index...
# index created!
