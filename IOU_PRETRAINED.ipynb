# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive
# Out:
# '2305490. Shreyashree Pani (1).pdf'
# '2305490. Shreyashree Pani.pdf'
#  AntiraggingAffidavitForm.pdf
# 'Assignment-1 (Aug 20, 2025 at 11:44 AM).jpg'
# 'Assignment 1.docx'
#  Classroom
# 'COA ASSIGNMENT-2(1).pdf'
# 'Colab Notebooks'
# 'Copy of Experiment 4.gdoc'
# 'Copy of Name of Google Form and Response sheet link for Quiz-II_DE & LA_2023.gsheet'
#  EVS.docx
# 'Experiment 4.gdoc'
# 'Image to pdf 26-Feb-2025.pdf'
#  IMG20231005184823.jpg
#  index.html
#  instances_val2017.json
#  java-assn.docx
# 'Java Programs (Q1-Q15).gdoc'
# 'JAVA SESSIONAL (1).docx'
# 'JAVA SESSIONAL.docx'
# 'nanotech (1).doc'
#  Notice_225.PDF
#  OOPJ7-Swing.ppt
#  RESUME_DIFF.pdf
# 'Scuba Andaman'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
#  val2017
# 'VisionExtract: Image Segmentation Project'
# 'WhatsApp Image 2025-07-21 at 21.50 (1).30_03c29977.jpg'
# 'WhatsApp Image 2025-07-21 at 21.50.30_03c29977.jpg'
# 'WhatsApp Image 2025-07-21 at 21.50.31_15218701 (1).jpg'
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ANN_FILE = "https://drive.google.com/file/d/1Utm9Dd1-eaKWwkD_jIYNX6zEC-UkEIj2/view?usp=sharing"
IMG_DIR  = "/content/drive/MyDrive/VisionAI/val2017"

# %%
import os
print("Annotation file exists:", os.path.exists(ANN_FILE))
print("Image folder exists:", os.path.exists(IMG_DIR))
# Out:
# Annotation file exists: False
# Image folder exists: True

# %%
import os

# Base folder where your VisionAI project is
BASE_DIR = "/content/drive/MyDrive/VisionAI"

# Search for .json files inside BASE_DIR and subfolders
json_files = []
for root, dirs, files in os.walk(BASE_DIR):
    for file in files:
        if file.endswith(".json"):
            json_files.append(os.path.join(root, file))

if not json_files:
    print("❌ No JSON annotation file found in VisionAI folder!")
else:
    # Take the first JSON file found (or modify if multiple)
    ANN_FILE = json_files[0]
    print("✅ Found annotation JSON file:", ANN_FILE)

# Optional: check that image folder exists
IMG_DIR = os.path.join(BASE_DIR, "val2017")
print("Image folder exists:", os.path.isdir(IMG_DIR))
# Out:
# ✅ Found annotation JSON file: /content/drive/MyDrive/VisionAI/instances_val2017.json
# Image folder exists: True

# %%
# =========================
# 1️⃣ Imports
# =========================
import os, random
import numpy as np
import cv2
import matplotlib.pyplot as plt
from pycocotools.coco import COCO
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import albumentations as A
from albumentations.pytorch import ToTensorV2

# =========================
# 2️⃣ Mount Google Drive
# =========================
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# =========================
# 3️⃣ Automatically find JSON annotation file
# =========================
BASE_DIR = "/content/drive/MyDrive/VisionAI"

json_files = []
for root, dirs, files in os.walk(BASE_DIR):
    for file in files:
        if file.endswith(".json"):
            json_files.append(os.path.join(root, file))

if not json_files:
    raise FileNotFoundError("❌ No JSON annotation file found in VisionAI folder!")
else:
    ANN_FILE = json_files[0]
    print("✅ Found annotation JSON file:", ANN_FILE)

# Image folder path
IMG_DIR = os.path.join(BASE_DIR, "val2017")
if not os.path.isdir(IMG_DIR):
    raise FileNotFoundError("❌ Image folder not found at: " + IMG_DIR)
print("✅ Image folder exists:", IMG_DIR)

# =========================
# 4️⃣ Parameters
# =========================
IMG_SIZE = 256
BATCH_SIZE = 8
EPOCHS = 20  # increase for better performance

# =========================
# 5️⃣ Load COCO and get image IDs
# =========================
coco = COCO(ANN_FILE)
img_ids = coco.getImgIds()
print("Total images available:", len(img_ids))

# =========================
# 6️⃣ Augmentation Pipelines
# =========================
train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomBrightnessContrast(p=0.3),
    A.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.1, rotate_limit=20, p=0.5),
    A.Normalize(),
])

val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(),
])

# =========================
# 7️⃣ Load image + mask with augmentation
# =========================
def load_image_and_mask_aug(img_id, augment=False):
    img_info = coco.loadImgs(img_id)[0]
    img_path = os.path.join(IMG_DIR, img_info["file_name"])

    # Read image
    image = cv2.imread(img_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Load mask
    ann_ids = coco.getAnnIds(imgIds=img_id, iscrowd=False)
    anns = coco.loadAnns(ann_ids)
    mask = np.zeros((img_info["height"], img_info["width"]), dtype=np.uint8)
    for ann in anns:
        mask = np.maximum(mask, coco.annToMask(ann))

    # Apply augmentation
    transform = train_transform if augment else val_transform
    augmented = transform(image=image, mask=mask)
    image = augmented['image']
    mask = np.expand_dims(augmented['mask'], axis=-1).astype(np.float32)

    return image, mask

# =========================
# 8️⃣ Dataset Generator
# =========================
class CocoDataset(keras.utils.Sequence):
    def __init__(self, img_ids, batch_size=BATCH_SIZE, augment=False):
        self.img_ids = img_ids
        self.batch_size = batch_size
        self.augment = augment

    def __len__(self):
        return int(np.ceil(len(self.img_ids) / self.batch_size))

    def __getitem__(self, idx):
        batch_ids = self.img_ids[idx*self.batch_size:(idx+1)*self.batch_size]
        images, masks = [], []
        for img_id in batch_ids:
            img, mask = load_image_and_mask_aug(img_id, augment=self.augment)
            images.append(img)
            masks.append(mask)
        return np.array(images, dtype=np.float32), np.array(masks, dtype=np.float32)

# =========================
# 9️⃣ Split train/val
# =========================
train_ids, val_ids = train_test_split(img_ids, test_size=0.2, random_state=42)
train_seq = CocoDataset(train_ids, augment=True)
val_seq   = CocoDataset(val_ids, augment=False)
print("Train samples:", len(train_ids))
print("Val samples:", len(val_ids))

# =========================
# 10️⃣ U-Net Architecture
# =========================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
    x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
    return x

def encoder_block(x, filters):
    f = conv_block(x, filters)
    p = layers.MaxPooling2D((2, 2))(f)
    return f, p

def decoder_block(x, skip, filters):
    us = layers.Conv2DTranspose(filters, 2, strides=2, padding="same")(x)
    concat = layers.Concatenate()([us, skip])
    f = conv_block(concat, filters)
    return f

def build_unet(input_shape=(IMG_SIZE, IMG_SIZE, 3)):
    inputs = layers.Input(input_shape)

    f1, p1 = encoder_block(inputs, 64)
    f2, p2 = encoder_block(p1, 128)
    f3, p3 = encoder_block(p2, 256)
    f4, p4 = encoder_block(p3, 512)

    bottleneck = conv_block(p4, 1024)

    d1 = decoder_block(bottleneck, f4, 512)
    d2 = decoder_block(d1, f3, 256)
    d3 = decoder_block(d2, f2, 128)
    d4 = decoder_block(d3, f1, 64)

    outputs = layers.Conv2D(1, (1,1), activation="sigmoid")(d4)
    model = keras.Model(inputs, outputs, name="U-Net")
    return model

# =========================
# 11️⃣ Loss and Metrics
# =========================
def dice_loss(y_true, y_pred, smooth=1e-7):
    intersection = tf.reduce_sum(y_true * y_pred)
    return 1 - (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    dl = dice_loss(y_true, y_pred)
    return bce + dl

def iou_metric(y_true, y_pred, smooth=1e-7):
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return (intersection + smooth) / (union + smooth)

def dice_metric(y_true, y_pred, smooth=1e-7):
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

# =========================
# 12️⃣ Compile model
# =========================
model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=bce_dice_loss,
    metrics=["accuracy", iou_metric, dice_metric]
)
model.summary()

# =========================
# 13️⃣ Training with Callbacks
# =========================
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint("best_unet_model.h5", save_best_only=True)
]

history = model.fit(
    train_seq,
    validation_data=val_seq,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# 14️⃣ Evaluate on Validation
# =========================
def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > 0.5).astype(np.float32)
    intersection = np.sum(y_true_f * y_pred_f)
    union = np.sum(y_true_f) + np.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = y_true.flatten()
    y_pred_f = (y_pred.flatten() > 0.5).astype(np.float32)
    intersection = np.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

def pixel_accuracy(y_true, y_pred):
    return np.mean(y_true == y_pred)

# Predict a validation batch
x_val, y_val = val_seq[0]
preds = model.predict(x_val)
preds_bin = (preds > 0.5).astype(np.float32)

iou = iou_coef(y_val, preds_bin)
dice = dice_coef(y_val, preds_bin)
pa = pixel_accuracy(y_val, preds_bin)
print(f"IoU: {iou:.4f}, Dice: {dice:.4f}, Pixel Acc: {pa:.4f}")

# =========================
# 15️⃣ Visualization
# =========================
# Metrics bar chart
metrics = {"IoU": iou, "Dice": dice, "Pixel Accuracy": pa}
plt.bar(metrics.keys(), metrics.values(), color=['skyblue','salmon','lightgreen'])
plt.title("Segmentation Metrics")
plt.ylim(0,1)
plt.show()

# Sample predictions
n_samples = 3
plt.figure(figsize=(15, n_samples*5))
for i in range(n_samples):
    plt.subplot(n_samples, 3, i*3+1)
    plt.imshow(x_val[i])
    plt.title("Original Image")
    plt.axis("off")

    plt.subplot(n_samples, 3, i*3+2)
    plt.imshow(y_val[i].squeeze(), cmap="gray")
    plt.title("Ground Truth Mask")
    plt.axis("off")

    plt.subplot(n_samples, 3, i*3+3)
    plt.imshow(preds_bin[i].squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")
plt.show()
# Out:
# Mounted at /content/drive
# ✅ Found annotation JSON file: /content/drive/MyDrive/VisionAI/instances_val2017.json
# ✅ Image folder exists: /content/drive/MyDrive/VisionAI/val2017
# loading annotations into memory...
# Done (t=0.50s)
# creating index...
# index created!
# Total images available: 5000
# Train samples: 4000
# Val samples: 1000
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Model: "U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ...
